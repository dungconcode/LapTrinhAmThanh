# %%
import numpy as np #thư viện hỗ trợ tính toán số học và đại số tuyến tính, được sử dụng để xử lý dữ liệu âm thanh và trích xuất đặc trưng
import pandas as pd #thư viện hỗ trợ xử lý dữ liệu dạng bảng, được sử dụng để lưu trữ và phân tích dữ liệu đặc trưng âm thanh
import scipy
import matplotlib.pyplot as plt, seaborn as sns #thư viện hỗ trợ vẽ đồ thị và trực quan hóa dữ liệu, được sử dụng để hiển thị các đặc trưng âm thanh và kết quả phân loại

from sklearn.preprocessing import StandardScaler#thư viện hỗ trợ chuẩn hóa dữ liệu, được sử dụng để chuẩn hóa các đặc trưng âm thanh trước khi đưa vào mô hình học máy

from sklearn.svm import SVC#thư viện hỗ trợ mô hình máy vector hỗ trợ (SVM), được sử dụng để xây dựng mô hình phân loại âm thanh
from sklearn.ensemble import RandomForestClassifier#thư viện hỗ trợ mô hình rừng ngẫu nhiên, được sử dụng để xây dựng mô hình phân loại âm thanh
from xgboost import XGBClassifier#thư viện hỗ trợ mô hình XGBoost, được sử dụng để xây dựng mô hình phân loại âm thanh

from sklearn.metrics import accuracy_score, f1_score, roc_auc_score, confusion_matrix, ConfusionMatrixDisplay, classification_report
from sklearn.model_selection import StratifiedKFold, train_test_split, GridSearchCV

import librosa, librosa.display
import IPython.display as ipd 



plt.rcParams['figure.figsize'] = (10, 3)

# %% [markdown]
# # Phân loại dựa trên các đặc trưng đã có sẵn

# %% [markdown]
# ## Tập Huấn luyện (Train Set)

# %%
from sqlalchemy import create_engine
from urllib.parse import quote_plus
import pandas as pd

db_config = {
    "host": "127.0.0.1",
    "user": "root",
    "password": quote_plus("22092005@Dung"),
    "database": "music_db",
    "port": 3306
}#cấu hình kết nối đến cơ sở dữ liệu MySQL, bao gồm địa chỉ máy chủ, tên người dùng, mật khẩu, tên cơ sở dữ liệu và cổng kết nối. Mật khẩu được mã hóa bằng hàm quote_plus để đảm bảo an toàn khi truyền qua URL.

engine = create_engine(
    f"mysql+pymysql://{db_config['user']}:{db_config['password']}@"
    f"{db_config['host']}:{db_config['port']}/{db_config['database']}"
)#tạo một đối tượng engine sử dụng SQLAlchemy để kết nối đến cơ sở dữ liệu MySQL, với chuỗi kết nối được xây dựng từ các thông tin cấu hình đã định nghĩa ở trên.

try:
    query = "SELECT * FROM songs_features"

    features_30_sec = pd.read_sql(
        query,
        con=engine
    )#thực thi câu lệnh SQL để truy vấn tất cả dữ liệu từ bảng "songs_features" trong cơ sở dữ liệu MySQL và lưu kết quả vào một DataFrame của pandas có tên là features_30_sec. DataFrame này sẽ chứa các đặc trưng âm thanh đã được trích xuất cho mỗi bài hát trong bảng "songs_features".

    data_each_song = features_30_sec

    print("Đã kết nối MySQL và tải dữ liệu thành công!")

    print(features_30_sec.head())

except Exception as e:
    print(f"Lỗi kết nối MySQL: {e}")
# Out:
# ✅ Đã kết nối MySQL và tải dữ liệu thành công!
#       filename  length  chroma_stft_mean  chroma_stft_var  rms_mean   rms_var  spectral_centroid_mean  spectral_centroid_var  spectral_bandwidth_mean  spectral_bandwidth_var  rolloff_mean   rolloff_var  zero_crossing_rate_mean  zero_crossing_rate_var  harmony_mean  harmony_var  perceptr_mean  perceptr_var       tempo  mfcc1_mean  mfcc1_var  mfcc2_mean  mfcc2_var  mfcc3_mean  mfcc3_var  mfcc4_mean  mfcc4_var  mfcc5_mean  mfcc5_var  mfcc6_mean  mfcc6_var  mfcc7_mean  mfcc7_var  mfcc8_mean  mfcc8_var  mfcc9_mean  mfcc9_var  mfcc10_mean  mfcc10_var  mfcc11_mean  mfcc11_var  mfcc12_mean  mfcc12_var  mfcc13_mean  mfcc13_var  mfcc14_mean  mfcc14_var  mfcc15_mean  mfcc15_var  mfcc16_mean  mfcc16_var  mfcc17_mean  mfcc17_var  mfcc18_mean  mfcc18_var  mfcc19_mean  mfcc19_var  mfcc20_mean  mfcc20_var  chroma_cqt_mean  chroma_cqt_var genre_label                              file_path
# 0  blues.00000  661500          0.349951         0.088752  0.130192  0.002830             1784.416546          129739.837273              2002.657106            85829.345949   3806.418650  9.013297e+05                 0.083066                0.000767     -0.000045     0.008172       0.000007      0.005704  123.046875   -113.6190    2570.81     121.553    295.724   -19.15110    235.580     42.3458    150.835    -6.37117    168.025     18.6130    89.1696   -13.69210    67.6048   15.339400    69.0631  -12.283600    82.1525     10.97380     63.4005     -8.32241     61.8105      8.80679     51.2920     -3.66580     41.2516      5.74594     40.5610     -5.16171     49.8235     0.750298     52.4641    -1.688360     36.5646    -0.409329     41.6436    -2.298870     55.0767     1.219950     46.9756         0.537760        0.053601       blues  genres_original/blues/blues.00000.wav
# 1  blues.00001  661500          0.340945         0.094968  0.095892  0.002374             1529.871314          376011.650353              2038.612143           213889.874085   3548.986873  2.976792e+06                 0.056044                0.001449      0.000142     0.005097      -0.000181      0.003067   67.999589   -207.5820    7770.77     123.997    560.163     8.93911    572.700     35.8708    264.855     2.91997    280.048     21.5188   156.4700    -8.55537   200.9700   23.355900   142.3720  -10.101000   166.2320     11.90640    104.3590     -5.55812    105.2240      5.37594     96.2992     -2.23783     64.9009      4.21713     73.1780     -6.01105     52.4850     0.932668     55.3643    -0.717028     60.1133     0.292333     48.1377    -0.285717     51.1312     0.532144     45.8232         0.476620        0.057748       blues  genres_original/blues/blues.00001.wav
# 2  blues.00002  661500          0.363562         0.085277  0.175494  0.002753             1552.637786          156538.294605              1747.382028            76150.688723   3041.089944  7.829465e+05                 0.076301                0.001007      0.000001     0.016350      -0.000016      0.007462  161.499023    -90.7763    3319.79     140.449    509.112   -29.10060    411.987     31.6873    144.148   -13.97600    156.016     25.7417    74.4693   -13.64470   106.6830   11.623100   106.6280  -11.775900    65.6854      9.70047     67.8455    -13.11530     57.6464      5.78576     64.6015     -8.89973     60.4764     -1.08702     57.7445     -9.21677     36.4674     2.453650     40.6202    -7.721790     47.7003    -1.816500     52.4182    -3.434350     46.6301    -2.231390     30.6262         0.443602        0.058805       blues  genres_original/blues/blues.00002.wav
# 3  blues.00003  661500          0.404848         0.094018  0.141139  0.006340             1070.110059          184506.655476              1596.244204           166637.568358   2185.061787  1.494194e+06                 0.033309                0.000423      0.000004     0.019063      -0.000018      0.002713   63.024009   -199.4620    5495.97     150.095    456.567     5.64917    257.047     26.8701    158.198     1.75544    267.902     14.2369   126.8820    -4.82887   156.0620    9.297850    81.1709   -0.753142    92.3619      8.14739     71.2231     -3.19524    110.3250      6.08535     48.1835     -2.47619     56.8134     -1.07622     62.2542     -2.87606     51.6464     0.776909     44.4570    -3.320060     50.2370     0.637263     37.3519    -0.617507     37.2912    -3.406940     31.9884         0.316822        0.071239       blues  genres_original/blues/blues.00003.wav
# 4  blues.00004  661500          0.308598         0.087850  0.091540  0.002305             1835.507008          343334.237032              1748.367477            88460.061216   3581.003346  1.572133e+06                 0.101500                0.001954     -0.000018     0.004818      -0.000010      0.003095  135.999178   -160.2920    5198.14     126.196    853.738   -35.60250    333.712     22.1512    193.673   -32.48760    336.451     10.8620   134.7970   -23.35720    93.3008    0.500523   124.7610  -11.804800   129.9890      1.20388     99.7952    -13.08510     80.3031     -2.80985     86.4920     -6.93562     89.6135     -7.55929     70.9325     -9.17215     75.7692    -4.510410     86.0128    -5.453740     75.3282    -0.924468     53.5776    -4.408080     62.9285   -11.701800     55.2151         0.497064        0.066060       blues  genres_original/blues/blues.00004.wav

# %% [markdown]
# Chia các bài hát thành tập huấn luyện (train) và tập kiểm tra (test) sử dụng bộ dữ liệu bản 30 giây

# %%
# CHỮA LỖI: Đổi từ 'label' thành 'genre_label' cho khớp với file CSV của bạn
X = data_each_song.drop(columns=['genre_label'])#tách các đặc trưng âm thanh từ DataFrame data_each_song bằng cách loại bỏ cột 'genre_label', và lưu kết quả vào biến X. Biến X sẽ chứa tất cả các cột đặc trưng âm thanh, trong khi cột 'genre_label' sẽ được sử dụng làm nhãn phân loại.
labels = data_each_song.loc[:, 'genre_label']#lấy cột 'genre_label' từ DataFrame data_each_song và lưu vào biến labels. Biến labels sẽ chứa các nhãn phân loại tương ứng với mỗi bài hát, được sử dụng làm mục tiêu (target) trong quá trình huấn luyện mô hình học máy.

cat_y = pd.Categorical(labels)#chuyển đổi cột 'genre_label' thành một đối tượng Categorical của pandas, giúp mã hóa các nhãn phân loại thành các mã số nguyên (integer codes) tương ứng. Biến cat_y sẽ chứa các nhãn phân loại đã được mã hóa dưới dạng các mã số nguyên, sẵn sàng để sử dụng trong quá trình huấn luyện mô hình học máy.
y = pd.Series(cat_y.codes)#tạo một Series của pandas từ các mã số nguyên của đối tượng Categorical cat_y và lưu vào biến y. Biến y sẽ chứa các nhãn phân loại đã được mã hóa dưới dạng các mã số nguyên, sẵn sàng để sử dụng làm mục tiêu (target) trong quá trình huấn luyện mô hình học máy.

print("Đã chia tách X và y thành công!")
print(f"Kích thước tập dữ liệu số X: {X.shape}")
# Out:
# ✅ Đã chia tách X và y thành công!
# Kích thước tập dữ liệu số X: (990, 62)

# %%
# train / test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, shuffle=True, random_state=123)

# %%
# songs to train
fn_train = np.sort(X_train.filename.values)

# songs to test
fn_test = np.sort(X_test.filename.values)

# %% [markdown]
# Chia 3 giây

# %%
data = features_30_sec

# %%
def bock_tach_songname(filename):
    # Phòng trường hợp dòng dữ liệu bị trống (NaN) hoặc không phải chuỗi
    if pd.isna(filename) or not isinstance(filename, str):
        return "unknown"
        
    parts = filename.split('.')
    # Nếu cấu trúc chuẩn có dấu chấm (Ví dụ: blues.00000 hoặc blues.00000.wav)
    if len(parts) >= 2:
        return parts[0] + '.' + parts[1]
    else:
        # Nếu không có dấu chấm (Ví dụ: blues_1 hoặc rock_test), lấy luôn tên đó
        return filename

# Sử dụng hàm .apply() để xử lý toàn bộ cột siêu tốc và an toàn
data['songname'] = data['filename'].apply(bock_tach_songname)

print("Đã tạo cột 'songname' cho bản 30s thành công (Đã chống lỗi IndexError)!")
print("-" * 50)
print(data['songname'].head())  # In thử 5 dòng đầu xem chuẩn đét chưa nha
# Out:
# ✅ Đã tạo cột 'songname' cho bản 30s thành công (Đã chống lỗi IndexError)!
# --------------------------------------------------
# 0    blues.00000
# 1    blues.00001
# 2    blues.00002
# 3    blues.00003
# 4    blues.00004
# Name: songname, dtype: str

# %%
song_data_ = []
for song in fn_train:
    song_data_.append(data[data.songname==song])
train_data = pd.concat(song_data_)

song_data_ = []
for song in fn_test:
    song_data_.append(data[data.songname==song])
test_data = pd.concat(song_data_)

# %%
X_train = train_data.select_dtypes(include=['number']).drop(columns=['length'], errors='ignore')
y_train = pd.Series(pd.Categorical(train_data.loc[:, 'genre_label']).codes)

X_test = test_data.select_dtypes(include=['number']).drop(columns=['length'], errors='ignore')
y_test = pd.Series(pd.Categorical(test_data.loc[:, 'genre_label']).codes)

print("Đã sửa cách lấy cột đặc trưng thành công!")
print(f"Kích thước X_train thực tế: {X_train.shape[0]} hàng, {X_train.shape[1]} cột.")
# Out:
# ✅ Đã sửa cách lấy cột đặc trưng thành công!
# Kích thước X_train thực tế: 693 hàng, 59 cột.

# %%
scaler = StandardScaler()
X_train_scaled = pd.DataFrame(scaler.fit_transform(X_train), columns=X_train.columns)

# %%
y_train.value_counts()
# Out:
# 4    76
# 0    72
# 5    72
# 6    72
# 1    71
# 7    70
# 8    69
# 2    68
# 9    65
# 3    58
# Name: count, dtype: int64

# %%
y_test.value_counts()
# Out:
# 3    41
# 9    34
# 2    32
# 8    30
# 7    29
# 1    28
# 0    27
# 6    27
# 5    26
# 4    23
# Name: count, dtype: int64

# %% [markdown]
# ## Model

# %%
svc = SVC(kernel='rbf')
rf = RandomForestClassifier()
# clf = AdaBoostClassifier()
# clf = GradientBoostingClassifier()
xgb = XGBClassifier(n_estimators=100)

# %% [markdown]
# **Hyperparameter tuning**

# %%
param_grid1 = {'C': [10, 100], 
              'gamma': [0.1, 0.01, 0.001]} 
cv = StratifiedKFold(n_splits=3, shuffle=True)  
grid1 = GridSearchCV(svc, param_grid1, cv=cv, verbose = 1)
grid1.fit(X_train_scaled, y_train)
print(grid1.best_estimator_)
# Out:
# Fitting 3 folds for each of 6 candidates, totalling 18 fits
# SVC(C=100, gamma=0.01)

# %%
param_grid2 = {'n_estimators': [50, 100],
               'max_depth': [None, 6, 12]}
cv = StratifiedKFold(n_splits=3, shuffle=True)
grid2 = GridSearchCV(rf, param_grid2, cv=cv, verbose = 1)
grid2.fit(X_train, y_train)
print(grid2.best_estimator_)
# Out:
# Fitting 3 folds for each of 6 candidates, totalling 18 fits
# RandomForestClassifier()

# %%
param_grid3 = {'learning_rate': [0.01, 0.1, 0.3, 0.5]}
cv = StratifiedKFold(n_splits=3, shuffle=True)
grid3 = GridSearchCV(xgb, param_grid3, cv=cv, verbose = 1)
grid3.fit(X_train, y_train)
print(grid3.best_estimator_)
# Out:
# Fitting 3 folds for each of 4 candidates, totalling 12 fits
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               feature_weights=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=0.3, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=100,
#               n_jobs=None, num_parallel_tree=None, ...)

# %% [markdown]
# **train**

# %%
clf1 = grid1.best_estimator_
clf1.fit(X_train_scaled, y_train)

clf2 = grid2.best_estimator_
clf2.fit(X_train, y_train)

clf3 = grid3.best_estimator_
clf3.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               feature_weights=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=0.3, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=100,
#               n_jobs=None, num_parallel_tree=None, ...)

# %% [markdown]
# **predict**

# %%
# for SVC
X_test_scaled = pd.DataFrame(scaler.transform(X_test), columns=X_test.columns)

# %%
y_true = y_test.copy()
y_pred1 = clf1.predict(X_test_scaled) # SVC
y_pred2 = clf2.predict(X_test)
y_pred3 = clf3.predict(X_test)

# %% [markdown]
# ## Results

# %%
print('SVM Accuracy: ', accuracy_score(y_true, y_pred1))
print('SVM F1: ', f1_score(y_true, y_pred1, average='macro'))

f,ax= plt.subplots(figsize=(8,8))
sns.heatmap(confusion_matrix(y_true, y_pred1), annot=True, square=True, 
            xticklabels=cat_y.categories, yticklabels=cat_y.categories, ax=ax)
ax.set_xlabel('Predicted labels')
ax.set_ylabel('True labels')
ax.set_title('Confusion Matrix (SVM)')
plt.show()
# Out:
# SVM Accuracy:  0.7104377104377104
# SVM F1:  0.7136856678930933

# %%
print("SVC classification report:",'\n')
print(classification_report(y_true, y_pred1))
print(dict(zip(cat_y.categories, range(10))))
# Out:
# SVC classification report:
#
#               precision    recall  f1-score   support
#
#            0       0.83      0.74      0.78        27
#            1       0.86      0.86      0.86        28
#            2       0.63      0.81      0.71        32
#            3       0.70      0.78      0.74        41
#            4       0.64      0.61      0.62        23
#            5       0.74      0.77      0.75        26
#            6       0.91      0.78      0.84        27
#            7       0.85      0.59      0.69        29
#            8       0.53      0.57      0.55        30
#            9       0.59      0.59      0.59        34
#
#     accuracy                           0.71       297
#    macro avg       0.73      0.71      0.71       297
# weighted avg       0.72      0.71      0.71       297
#
# {'blues': 0, 'classical': 1, 'country': 2, 'disco': 3, 'hiphop': 4, 'jazz': 5, 'metal': 6, 'pop': 7, 'reggae': 8, 'rock': 9}

# %%
print('RF Accuracy: ', accuracy_score(y_true, y_pred2))
print('RF F1: ', f1_score(y_true, y_pred2, average='macro'))

f,ax= plt.subplots(figsize=(8,8))
sns.heatmap(confusion_matrix(y_true, y_pred2), annot=True, square=True, 
            xticklabels=cat_y.categories, yticklabels=cat_y.categories, ax=ax)
ax.set_xlabel('Predicted labels')
ax.set_ylabel('True labels')
ax.set_title('Confusion Matrix (Random Forest)')
plt.show()
# Out:
# RF Accuracy:  0.6498316498316499
# RF F1:  0.6549691312111011

# %%
print("RF classification report:",'\n')
print(classification_report(y_true, y_pred2))
print(dict(zip(cat_y.categories, range(10))))
# Out:
# RF classification report:
#
#               precision    recall  f1-score   support
#
#            0       0.74      0.63      0.68        27
#            1       0.83      0.89      0.86        28
#            2       0.59      0.69      0.64        32
#            3       0.59      0.56      0.57        41
#            4       0.62      0.57      0.59        23
#            5       0.69      0.85      0.76        26
#            6       0.71      0.81      0.76        27
#            7       0.89      0.55      0.68        29
#            8       0.51      0.67      0.58        30
#            9       0.48      0.38      0.43        34
#
#     accuracy                           0.65       297
#    macro avg       0.67      0.66      0.65       297
# weighted avg       0.66      0.65      0.65       297
#
# {'blues': 0, 'classical': 1, 'country': 2, 'disco': 3, 'hiphop': 4, 'jazz': 5, 'metal': 6, 'pop': 7, 'reggae': 8, 'rock': 9}

# %%
print('XGB Accuracy: ', accuracy_score(y_true, y_pred3))
print('XGB F1: ', f1_score(y_true, y_pred3, average='macro'))

f,ax= plt.subplots(figsize=(8,8))
sns.heatmap(confusion_matrix(y_true, y_pred3), annot=True, square=True, 
            xticklabels=cat_y.categories, yticklabels=cat_y.categories, ax=ax)
ax.set_xlabel('Predicted labels')
ax.set_ylabel('True labels')
ax.set_title('Confusion Matrix (XGBoost)')
plt.show()
# Out:
# XGB Accuracy:  0.6632996632996633
# XGB F1:  0.6735801982508173

# %%
print("XGB classification report:",'\n')
print(classification_report(y_true, y_pred3))
print(dict(zip(cat_y.categories, range(10))))
# Out:
# XGB classification report:
#
#               precision    recall  f1-score   support
#
#            0       0.81      0.63      0.71        27
#            1       0.89      0.86      0.87        28
#            2       0.59      0.75      0.66        32
#            3       0.61      0.46      0.53        41
#            4       0.47      0.65      0.55        23
#            5       0.74      0.77      0.75        26
#            6       0.79      0.85      0.82        27
#            7       0.87      0.69      0.77        29
#            8       0.56      0.63      0.59        30
#            9       0.50      0.47      0.48        34
#
#     accuracy                           0.66       297
#    macro avg       0.68      0.68      0.67       297
# weighted avg       0.68      0.66      0.66       297
#
# {'blues': 0, 'classical': 1, 'country': 2, 'disco': 3, 'hiphop': 4, 'jazz': 5, 'metal': 6, 'pop': 7, 'reggae': 8, 'rock': 9}

# %% [markdown]
# ## interpretation

# %% [markdown]
# - As a result of checking the performance of the classifier by targeting the genre for 3 seconds(1/10 part) of each song, it can be seen that the accuracy and F1 score are about 69%. XGboost shows highest performace scores among the models
#
# - As you can see in the confusion matrix some specific genres are misclassified. Let's check this case by case.
#
# - First of all, let's look at which genre was most mis-predicted for each genre. (RF based)
#      - **Blues**: Country 31, Metal 23, etc.
#      - **Classical** (high score - well classified): Jazz 12
#      - **Country**: Blues 35, Rock 18, etc.
#      - **Disco**: Hip Hop 55, Metal 31, Rock 31, etc.
#      - **Hip Hop**: Pop 32, Reggae 19
#      - **Jazz**: Classic 23
#      - **Metal**: Blues 17, Rock 14, etc.
#      - **Pop**: Hip Hop 30, Disco 17, etc.
#      - **Reggae**: Country 24, Hip Hop 23, etc.
#      - **Rock** (low score): Metal 69, Disco 4, etc.
#
# - Looking at the misclassified genres, we can see the pairs: **blues-country, classical-jazz, disco-hip-hop, pop-hip-hop, hip-hop-reggae, metal-rock**. Intuitively, it is mainly genre pairs that are generally thought to have genre similarities (but there are some pairs that are not; **metal-blues, raggae-country**; maybe they have some similar musical characteristics)
#
# - In other words, it can be inferred that the feature based on the given audio content has some musical characteristic information, similar to the genre artificially classified by people.

# %% [markdown]
# ## feature importance

# %%
fig, ax = plt.subplots(figsize=(8,12))
from xgboost import plot_importance
plot_importance(clf3, ax=ax, title='Feature Importance of XGBoost model')
plt.show()

# %% [markdown]
# - hamornic, percussive time series features have high importance.
# - spectral features have relatively low importance.
# - mfcc features variance have very low importance.

# %% [markdown]
# ## without variance features
#
# - excluding variances
# - for simplicity only using xgboost with default parameters

# %%
feat_names = [col for col in train_data.columns if 'mean' in col] # only mean data

# %%
# CHỮA LỖI: Đổi từ 'label' thành 'genre_label' cho khớp với file 30s của bạn
X_train = train_data.loc[:, feat_names]
y_train = pd.Series(pd.Categorical(train_data.loc[:, 'genre_label']).codes)

X_test = test_data.loc[:, feat_names]
y_test = pd.Series(pd.Categorical(test_data.loc[:, 'genre_label']).codes)

print("✅ Đã chia tập Train/Test theo danh sách cột và mã hóa nhãn 30s thành công!")
print(f"Số lượng mẫu - Tập Train: {len(X_train)} bài | Tập Test: {len(X_test)} bài")
# Out:
# ✅ Đã chia tập Train/Test theo danh sách cột và mã hóa nhãn 30s thành công!
# Số lượng mẫu - Tập Train: 693 bài | Tập Test: 297 bài

# %%
xgb = XGBClassifier(n_estimators=100, learning_rate=0.5)
xgb.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               feature_weights=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=0.5, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=100,
#               n_jobs=None, num_parallel_tree=None, ...)

# %%
y_true = y_test.copy()
y_pred4 = xgb.predict(X_test)

# %%
print('XGB Accuracy: ', accuracy_score(y_true, y_pred4))
print('XGB F1: ', f1_score(y_true, y_pred4, average='macro'))

f,ax= plt.subplots(figsize=(8,8))
sns.heatmap(confusion_matrix(y_true, y_pred4), annot=True, square=True, 
            xticklabels=cat_y.categories, yticklabels=cat_y.categories, ax=ax)
ax.set_xlabel('Predicted labels')
ax.set_ylabel('True labels')
ax.set_title('Confusion Matrix (XGBoost)')
plt.show()
# Out:
# XGB Accuracy:  0.6430976430976431
# XGB F1:  0.6487200189841322

# %% [markdown]
# - lower scores but not that bad

# %%
fig, ax = plt.subplots(figsize=(8,12))
plot_importance(xgb, ax=ax, title='Feature Importance of XGBoost model')
plt.show()

# %%
import warnings
warnings.filterwarnings("ignore", category=UserWarning)
import os
import librosa
import numpy as np
import pandas as pd

# =================================================================

# 1. ĐỊNH NGHĨA HÀM DỰ ĐOÁN (BẮT BUỘC PHẢI CHẠY DÒNG NÀY TRƯỚC)

# =================================================================
def predict_genre_of_file(song_path, model, scaler, categories):
    try:
        # 1. Tải file âm thanh trọn vẹn 30 giây
        y, sr = librosa.load(song_path, duration=30.0)  
        # 2. Trích xuất toàn bộ các đặc trưng nâng cao
        tempo, _ = librosa.beat.beat_track(y=y, sr=sr)
        chroma_stft = librosa.feature.chroma_stft(y=y, sr=sr)
        rmse = librosa.feature.rms(y=y)
        spec_cent = librosa.feature.spectral_centroid(y=y, sr=sr)
        spec_bw = librosa.feature.spectral_bandwidth(y=y, sr=sr)
        rolloff = librosa.feature.spectral_rolloff(y=y, sr=sr)
        zcr = librosa.feature.zero_crossing_rate(y=y)
        mfcc = librosa.feature.mfcc(y=y, sr=sr, n_mfcc=20)
        harmony_wave = librosa.effects.harmonic(y)
        percussive_wave = librosa.effects.percussive(y)
        chroma_cqt = librosa.feature.chroma_cqt(y=y, sr=sr)
        features = {
            'length': len(y),
            'chroma_stft_mean': np.mean(chroma_stft), 'chroma_stft_var': np.var(chroma_stft),
            'rms_mean': np.mean(rmse), 'rms_var': np.var(rmse),
            'spectral_centroid_mean': np.mean(spec_cent), 'spectral_centroid_var': np.var(spec_cent),
            'spectral_bandwidth_mean': np.mean(spec_bw), 'spectral_bandwidth_var': np.var(spec_bw),
            'rolloff_mean': np.mean(rolloff), 'rolloff_var': np.var(rolloff),
            'zero_crossing_rate_mean': np.mean(zcr), 'zero_crossing_rate_var': np.var(zcr),
            'harmony_mean': np.mean(harmony_wave), 'harmony_var': np.var(harmony_wave),
            'perceptr_mean': np.mean(percussive_wave), 'perceptr_var': np.var(percussive_wave),
            'tempo': tempo[0] if isinstance(tempo, (list, np.ndarray)) else tempo,
            'chroma_cqt_mean': np.mean(chroma_cqt), 'chroma_cqt_var': np.var(chroma_cqt)
        }
        for i in range(20):
            features[f'mfcc{i+1}_mean'] = np.mean(mfcc[i])
            features[f'mfcc{i+1}_var'] = np.var(mfcc[i])
        df_song = pd.DataFrame([features])
        if hasattr(scaler, 'feature_names_in_'):
            model_features = scaler.feature_names_in_
            df_song = df_song.reindex(columns=model_features)
        df_song_scaled = scaler.transform(df_song)
        pred_code = model.predict(df_song_scaled)[0]
        return categories[pred_code].upper()
    except Exception as e:
        return f"LỖI (Quá trình trích xuất thất bại: {e})"

# =================================================================

# 2. ĐOẠN QUÉT CẤU TRÚC THƯ MỤC MUSIC_TEST VÀ XUẤT BÁO CÁO

# =================================================================

FOLDER_TEST = "music_test"
if not os.path.exists(FOLDER_TEST):
    print(f"Bạn chưa tạo folder '{FOLDER_TEST}' hoặc để sai vị trí rồi!")
else:
    valid_extensions = ('.wav', '.mp3', '.m4a', '.flac')
    testcase_records = []
    stt = 1
    correct_count = 0
    total_files = 0
    print(f"Hệ thống bắt đầu quét cấu trúc thư mục trong '{FOLDER_TEST}'...")
    print("-" * 90)
    for root, dirs, files in os.walk(FOLDER_TEST):
        music_files = [f for f in files if f.lower().endswith(valid_extensions)]
        if not music_files:
            continue
        expected_genre = os.path.basename(root).upper()
        for file_name in music_files:
            total_files += 1
            full_path = os.path.join(root, file_name)
            # Gọi hàm dự đoán vừa định nghĩa ở trên (Hết lỗi NameError)
            prediction = predict_genre_of_file(
                song_path=full_path,
                model=clf1,                  
                scaler=scaler,              
                categories=cat_y.categories  
            )
            if expected_genre == prediction:
                status = "PASS ✅"
                correct_count += 1
            else:
                status = "FAIL ❌"
            testcase_records.append({
                'STT': stt,
                'Tên File': file_name,
                'Thể loại gốc (Kỳ vọng)': expected_genre,
                'AI Dự đoán (Thực tế)': prediction,
                'Trạng thái': status
            })
            stt += 1
    if total_files == 0:
        print(f"Thư mục '{FOLDER_TEST}' đang trống rỗng, không có file nhạc phù hợp.")
    else:
        df_report = pd.DataFrame(testcase_records)
        pd.set_option('display.max_columns', None)
        pd.set_option('display.width', 1000)
        print("\nBẢNG KẾT QUẢ KIỂM THỬ (TESTCASE REPORT):")
        print(df_report.to_string(index=False))
        print("-" * 90)
        accuracy = (correct_count / total_files) * 100
        print(f"🎉 Kết quả bộ testcase: ĐÚNG {correct_count}/{total_files} bài (Độ chính xác: {accuracy:.2f}%)")
        df_report.to_csv("Bao_cao_Testcase_Phan_Cap.csv", index=False, encoding='utf-8-sig')
        print("File báo cáo đã được lưu thành công!")
# Out:
# 🚀 Hệ thống bắt đầu quét cấu trúc thư mục trong 'music_test'...
# ------------------------------------------------------------------------------------------
#
# 📊 BẢNG KẾT QUẢ KIỂM THỬ (TESTCASE REPORT):
#  STT        Tên File Thể loại gốc (Kỳ vọng) AI Dự đoán (Thực tế) Trạng thái
#    1     blues_1.wav                  BLUES                BLUES     PASS ✅
#    2     blues_2.wav                  BLUES               REGGAE     FAIL ❌
#    3     blues_4.wav                  BLUES              COUNTRY     FAIL ❌
#    4     blues_5.wav                  BLUES                BLUES     PASS ✅
#    5 classical_1.wav              CLASSICAL            CLASSICAL     PASS ✅
#    6 classical_2.wav              CLASSICAL            CLASSICAL     PASS ✅
#    7 classical_3.wav              CLASSICAL            CLASSICAL     PASS ✅
#    8 classical_4.wav              CLASSICAL            CLASSICAL     PASS ✅
#    9 classical_5.wav              CLASSICAL            CLASSICAL     PASS ✅
#   10     disco_1.wav                  DISCO                DISCO     PASS ✅
#   11     disco_2.wav                  DISCO            CLASSICAL     FAIL ❌
#   12     disco_3.wav                  DISCO                DISCO     PASS ✅
#   13     disco_4.wav                  DISCO                 ROCK     FAIL ❌
#   14     disco_5.wav                  DISCO                DISCO     PASS ✅
#   15    hiphop_1.wav                 HIPHOP               HIPHOP     PASS ✅
#   16    hiphop_2.mp3                 HIPHOP               HIPHOP     PASS ✅
#   17      jazz_1.wav                   JAZZ                 JAZZ     PASS ✅
#   18      jazz_2.wav                   JAZZ              COUNTRY     FAIL ❌
#   19      jazz_3.wav                   JAZZ                 JAZZ     PASS ✅
#   20      jazz_5.wav                   JAZZ                 JAZZ     PASS ✅
#   21     metal_1.wav                  METAL               HIPHOP     FAIL ❌
#   22       pop_1.wav                    POP                  POP     PASS ✅
#   23       pop_2.wav                    POP               HIPHOP     FAIL ❌
#   24       pop_3.wav                    POP                  POP     PASS ✅
#   25       pop_4.wav                    POP                 ROCK     FAIL ❌
#   26    reggae_1.wav                 REGGAE                METAL     FAIL ❌
#   27      rock_1.mp3                   ROCK                METAL     FAIL ❌
#   28      rock_2.wav                   ROCK                 ROCK     PASS ✅
#   29      rock_3.wav                   ROCK                  POP     FAIL ❌
#   30      rock_4.wav                   ROCK                 ROCK     PASS ✅
#   31      rock_5.wav                   ROCK                 ROCK     PASS ✅
# ------------------------------------------------------------------------------------------
# 🎉 Kết quả bộ testcase: ĐÚNG 20/31 bài (Độ chính xác: 64.52%)
# 💾 File báo cáo đã được lưu thành công!

# %%
# !pip install gradio
# Out:
# Requirement already satisfied: gradio in C:\Users\lequo\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (6.15.1)
# Requirement already satisfied: anyio<5.0,>=3.0 in C:\Users\lequo\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from gradio) (4.13.0)
# Requirement already satisfied: audioop-lts<=0.2.2 in C:\Users\lequo\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from gradio) (0.2.2)
# Requirement already satisfied: brotli>=1.1.0 in C:\Users\lequo\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from gradio) (1.2.0)
# Requirement already satisfied: fastapi<1.0,>=0.115.2 in C:\Users\lequo\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from gradio) (0.136.3)
# Requirement already satisfied: gradio-client==2.5.0 in C:\Users\lequo\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from gradio) (2.5.0)
# Requirement already satisfied: groovy~=0.1 in C:\Users\lequo\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from gradio) (0.1.2)
# Requirement already satisfied: hf-gradio<1.0,>=0.4.1 in C:\Users\lequo\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from gradio) (0.4.1)
# Requirement already satisfied: httpx<1.0,>=0.24.1 in C:\Users\lequo\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from gradio) (0.28.1)
# Requirement already satisfied: huggingface-hub<2.0,>=0.33.5 in C:\Users\lequo\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from gradio) (1.16.4)
# Requirement already satisfied: jinja2<4.0 in C:\Users\lequo\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from gradio) (3.1.6)
# Requirement already satisfied: markupsafe<4.0,>=2.0 in C:\Users\lequo\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from gradio) (3.0.3)
# Requirement already satisfied: numpy<3.0,>=1.0 in C:\Users\lequo\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from gradio) (2.4.6)
# Requirement already satisfied: orjson~=3.0 in C:\Users\lequo\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from gradio) (3.11.9)
# Requirement already satisfied: packaging in C:\Users\lequo\AppData\Roaming\Python\Python314\site-packages (from gradio) (26.2)
# Requirement already satisfied: pandas<4.0,>=1.0 in C:\Users\lequo\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from gradio) (3.0.3)
# Requirement already satisfied: pillow<13.0,>=8.0 in C:\Users\lequo\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from gradio) (12.2.0)
# Requirement already satisfied: pydantic<=3.0,>=2.0 in C:\Users\lequo\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from gradio) (2.13.4)
# Requirement already satisfied: pydub<1.0 in C:\Users\lequo\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from gradio) (0.25.1)
# Requirement already satisfied: python-multipart<1.0,>=0.0.18 in C:\Users\lequo\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from gradio) (0.0.29)
# Requirement already satisfied: pytz>=2017.2 in C:\Users\lequo\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from gradio) (2026.2)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in C:\Users\lequo\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from gradio) (6.0.3)
# Requirement already satisfied: safehttpx<0.2.0,>=0.1.7 in C:\Users\lequo\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from gradio) (0.1.7)
# Requirement already satisfied: semantic-version~=2.0 in C:\Users\lequo\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from gradio) (2.10.0)
# Requirement already satisfied: starlette<2.0,>=0.40.0 in C:\Users\lequo\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from gradio) (1.1.0)
# Requirement already satisfied: tomlkit<0.15.0,>=0.12.0 in C:\Users\lequo\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from gradio) (0.14.0)
# Requirement already satisfied: typer<1.0,>=0.12 in C:\Users\lequo\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from gradio) (0.25.1)
# Requirement already satisfied: typing-extensions~=4.0 in C:\Users\lequo\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from gradio) (4.15.0)
# Requirement already satisfied: uvicorn>=0.14.0 in C:\Users\lequo\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from gradio) (0.48.0)
# Requirement already satisfied: fsspec in C:\Users\lequo\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from gradio-client==2.5.0->gradio) (2026.4.0)
# Requirement already satisfied: idna>=2.8 in C:\Users\lequo\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from anyio<5.0,>=3.0->gradio) (3.16)
# Requirement already satisfied: typing-inspection>=0.4.2 in C:\Users\lequo\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from fastapi<1.0,>=0.115.2->gradio) (0.4.2)
# Requirement already satisfied: annotated-doc>=0.0.2 in C:\Users\lequo\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from fastapi<1.0,>=0.115.2->gradio) (0.0.4)
# Requirement already satisfied: certifi in C:\Users\lequo\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from httpx<1.0,>=0.24.1->gradio) (2026.5.20)
# Requirement already satisfied: httpcore==1.* in C:\Users\lequo\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from httpx<1.0,>=0.24.1->gradio) (1.0.9)
# Requirement already satisfied: h11>=0.16 in C:\Users\lequo\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from httpcore==1.*->httpx<1.0,>=0.24.1->gradio) (0.16.0)
# Requirement already satisfied: click>=8.4.0 in C:\Users\lequo\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from huggingface-hub<2.0,>=0.33.5->gradio) (8.4.1)
# Requirement already satisfied: filelock>=3.10.0 in C:\Users\lequo\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from huggingface-hub<2.0,>=0.33.5->gradio) (3.29.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.3 in C:\Users\lequo\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from huggingface-hub<2.0,>=0.33.5->gradio) (1.5.0)
# Requirement already satisfied: tqdm>=4.42.1 in C:\Users\lequo\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from huggingface-hub<2.0,>=0.33.5->gradio) (4.67.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\lequo\AppData\Roaming\Python\Python314\site-packages (from pandas<4.0,>=1.0->gradio) (2.9.0.post0)
# Requirement already satisfied: tzdata in C:\Users\lequo\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from pandas<4.0,>=1.0->gradio) (2026.2)
# Requirement already satisfied: annotated-types>=0.6.0 in C:\Users\lequo\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from pydantic<=3.0,>=2.0->gradio) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in C:\Users\lequo\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from pydantic<=3.0,>=2.0->gradio) (2.46.4)
# Requirement already satisfied: shellingham>=1.3.0 in C:\Users\lequo\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from typer<1.0,>=0.12->gradio) (1.5.4)
# Requirement already satisfied: rich>=13.8.0 in C:\Users\lequo\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from typer<1.0,>=0.12->gradio) (15.0.0)
# Requirement already satisfied: colorama in C:\Users\lequo\AppData\Roaming\Python\Python314\site-packages (from click>=8.4.0->huggingface-hub<2.0,>=0.33.5->gradio) (0.4.6)
# Requirement already satisfied: six>=1.5 in C:\Users\lequo\AppData\Roaming\Python\Python314\site-packages (from python-dateutil>=2.8.2->pandas<4.0,>=1.0->gradio) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in C:\Users\lequo\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from rich>=13.8.0->typer<1.0,>=0.12->gradio) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in C:\Users\lequo\AppData\Roaming\Python\Python314\site-packages (from rich>=13.8.0->typer<1.0,>=0.12->gradio) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in C:\Users\lequo\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer<1.0,>=0.12->gradio) (0.1.2)

# %%
import os
import librosa
import numpy as np
import pandas as pd
import gradio as gr
import traceback
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC

# ==============================================================================
# 🏋️ BƯỚC 1: TỰ ĐỘNG KHỞI TẠO VÀ HUẤN LUYỆN AI 30S TẠI CHỖ (HÀM TỰ ĐỘNG)
# ==============================================================================
print("⏳ Hệ thống đang kiểm tra và nạp bộ nhớ AI bản 30s... Vui lòng đợi...")

try:
    # Đọc file dữ liệu gốc 30s của bạn
    data_each_song = pd.read_csv('example_features.csv')
    
    # Tách X, y và chữa lỗi lệch tên cột 'label' thành 'genre_label'
    X = data_each_song.drop(columns=['genre_label', 'filename'], errors='ignore')
    labels = data_each_song.loc[:, 'genre_label']
    cat_y = pd.Categorical(labels)
    y = pd.Series(cat_y.codes)
    
    # Chia tập dữ liệu Train/Test tỉ lệ 70/30 theo chuẩn tác giả
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, shuffle=True, random_state=123, stratify=y)
    
    # Chuẩn hóa dữ liệu bằng StandardScaler
    scaler = StandardScaler()
    X_train_scaled = scaler.fit_transform(X_train)
    
    # Huấn luyện mô hình SVM gốc (clf1)
    clf1 = SVC(C=10, gamma=0.01, probability=True) # Bật probability để sau này cần tính tỷ lệ %
    clf1.fit(X_train_scaled, y_train)
    
    # Lưu danh sách thể loại nhạc để App gọi
    categories_list = cat_y.categories
    print("✅ ĐÃ NẠP ĐẠN THÀNH CÔNG! Mô hình SVM 30s đã sẵn sàng chiến đấu.")
except Exception as init_error:
    print(f"❌ Cảnh báo nạp dữ liệu thất bại: {init_error}")
    print("👉 Hãy chắc chắn file 'example_features.csv' đang nằm chung thư mục với file code này.")

# ==============================================================================
# 🎵 BƯỚC 2: HÀM TRÍCH XUẤT ĐẶC TRƯNG VÀ DỰ ĐOÁN FILE PHÁT SINH
# ==============================================================================
def predict_genre_of_file(song_path, model, scaler, categories):
    # 1. Tải file âm thanh trọn vẹn 30 giây
    y, sr = librosa.load(song_path, duration=30.0) 
    
    # 2. Trích xuất toàn bộ các đặc trưng nâng cao
    tempo, _ = librosa.beat.beat_track(y=y, sr=sr)
    chroma_stft = librosa.feature.chroma_stft(y=y, sr=sr)
    rmse = librosa.feature.rms(y=y)
    spec_cent = librosa.feature.spectral_centroid(y=y, sr=sr)
    spec_bw = librosa.feature.spectral_bandwidth(y=y, sr=sr)
    rolloff = librosa.feature.spectral_rolloff(y=y, sr=sr)
    zcr = librosa.feature.zero_crossing_rate(y=y)
    mfcc = librosa.feature.mfcc(y=y, sr=sr, n_mfcc=20)
    
    harmony_wave = librosa.effects.harmonic(y)
    percussive_wave = librosa.effects.percussive(y)
    chroma_cqt = librosa.feature.chroma_cqt(y=y, sr=sr)
    
    features = {
        'length': len(y),
        'chroma_stft_mean': np.mean(chroma_stft), 'chroma_stft_var': np.var(chroma_stft),
        'rms_mean': np.mean(rmse), 'rms_var': np.var(rmse),
        'spectral_centroid_mean': np.mean(spec_cent), 'spectral_centroid_var': np.var(spec_cent),
        'spectral_bandwidth_mean': np.mean(spec_bw), 'spectral_bandwidth_var': np.var(spec_bw),
        'rolloff_mean': np.mean(rolloff), 'rolloff_var': np.var(rolloff),
        'zero_crossing_rate_mean': np.mean(zcr), 'zero_crossing_rate_var': np.var(zcr),
        'harmony_mean': np.mean(harmony_wave), 'harmony_var': np.var(harmony_wave),
        'perceptr_mean': np.mean(percussive_wave), 'perceptr_var': np.var(percussive_wave),
        'tempo': tempo[0] if isinstance(tempo, (list, np.ndarray)) else tempo,
        'chroma_cqt_mean': np.mean(chroma_cqt), 'chroma_cqt_var': np.var(chroma_cqt)
    }
    for i in range(20):
        features[f'mfcc{i+1}_mean'] = np.mean(mfcc[i])
        features[f'mfcc{i+1}_var'] = np.var(mfcc[i])
        
    # 3. Ép DataFrame bài hát mới nhận ĐÚNG THỨ TỰ CỘT mà bộ chuẩn hóa yêu cầu
    df_song = pd.DataFrame([features])
    if hasattr(scaler, 'feature_names_in_'):
        df_song = df_song.reindex(columns=scaler.feature_names_in_)
    
    # Chuẩn hóa dữ liệu và dự đoán
    df_song_scaled = scaler.transform(df_song)
    pred_code = model.predict(df_song_scaled)[0]
    return categories[pred_code].upper()

# ==============================================================================
# 🚀 BƯỚC 3: HÀM ĐIỀU PHỐI GIAO DIỆN GRADIO
# ==============================================================================
def gradio_predict(audio_file):
    if audio_file is None:
        return "❌ Vui lòng kéo thả hoặc chọn một file nhạc trước khi bấm dự đoán!"
    
    try:
        print(f"📥 Đang xử lý file nhạc: {audio_file}")
        
        # Gọi hàm xử lý lõi với các biến đã được tự động định nghĩa ở Bước 1
        prediction = predict_genre_of_file(
            song_path=audio_file,
            model=clf1,
            scaler=scaler,
            categories=categories_list
        )
        return f"🎵 Dự đoán thể loại: {prediction}"
        
    except Exception as e:
        error_msg = traceback.format_exc()
        print(f"❌ Chi tiết lỗi hệ thống:\n{error_msg}")
        return f"❌ Lỗi trích xuất đặc trưng âm thanh: {str(e)}"

# ==============================================================================
# 🎨 BƯỚC 4: THIẾT KẾ VÀ KHỞI CHẠY GIAO DIỆN WEB
# ==============================================================================
with gr.Blocks(theme=gr.themes.Soft(), title="AI Phân Biệt Thể Loại Nhạc") as demo:
    
    gr.Markdown(
        """
        # 🎵 HỆ THỐNG AI PHÂN BIỆT THỂ LOẠI NHẠC (BẢN 30 GIÂY ĐỒNG BỘ)
        Ứng dụng sử dụng mô hình học máy **SVM** kết hợp với thư viện xử lý âm thanh **Librosa** để phân tích dải tần số âm thanh, nhịp điệu (Tempo) và MFCC nhằm nhận diện thể loại nhạc.
        """
    )
    
    with gr.Row():
        with gr.Column():
            input_audio = gr.Audio(
                label="Tải file nhạc của bạn lên tại đây", 
                type="filepath"
            )
            btn_predict = gr.Button("🔮 Bắt đầu phân tích & Dự đoán", variant="primary")
            
        with gr.Column():
            output_text = gr.Textbox(
                label="🤖 Kết quả từ AI", 
                placeholder="Kết quả dự đoán sẽ hiển thị ở đây...",
                text_align="center"
            )
            
    btn_predict.click(
        fn=gradio_predict, 
        inputs=input_audio, 
        outputs=output_text
    )

# Mở giao diện ứng dụng web
demo.launch(share=False)
# Out:
# ⏳ Hệ thống đang kiểm tra và nạp bộ nhớ AI bản 30s... Vui lòng đợi...
# ✅ ĐÃ NẠP ĐẠN THÀNH CÔNG! Mô hình SVM 30s đã sẵn sàng chiến đấu.
# * Running on local URL:  http://127.0.0.1:7863
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7863/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
import joblib

# Lưu bộ chuẩn hóa dữ liệu và con AI SVM 30s vào ổ đĩa
joblib.dump(scaler, 'music_scaler.pkl')
joblib.dump(clf1, 'music_svm_model.pkl')

# Lưu luôn cả danh sách các thể loại nhạc (categories) để app.py đọc lại
joblib.dump(cat_y.categories, 'music_categories.pkl')

print("ĐÃ LƯU THÀNH CÔNG 3 FILE: 'music_scaler.pkl', 'music_svm_model.pkl', 'music_categories.pkl'")
print("Giờ bạn có thể tắt Jupyter Notebook và chuyển sang chạy app.py độc lập!")
# Out:
# 💾 ĐÃ LƯU THÀNH CÔNG 3 FILE: 'music_scaler.pkl', 'music_svm_model.pkl', 'music_categories.pkl'
# 👉 Giờ bạn có thể tắt Jupyter Notebook và chuyển sang chạy app.py độc lập!
